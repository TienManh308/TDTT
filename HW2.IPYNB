# %%
#1.1
n = int(input("Enter a positive integer: "))
print(2 * n)
# Out:
# 10

# %%
#1.2
a, b = map(float, input("Enter two numbers (a b): ").split())
s1 = a * a / 4 * 3.14
s2 = a * b
print(round(s2 - s1, 2))
# Out:
# 1.21

# %%
#1.3
st = input("Enter a string: ")
if 'a' <= st <= 'z':
    print(st.upper())
else:
    print(st.lower())
# Out:
# z

# %%
#1.4
st = input('nhap ky tu: ')
if st.isalpha():
    print(f"{st} la ky tu alphabet")
else:
    print(f"{st} khong la ky tu alphabet")
# Out:
# B la ky tu alphabet

# %%
#1.5
a,b = map(int, input("Nhap hai so nguyen: ").split())
if a == b:
    print("Hai so bang nhau")
elif(a > b):
    print(f"{a} lon hon {b}")

# %%
#1.6
a,b,c = map(float, input("nhap ky tu a b c: ").split())
if (a + b > c) and (a + c > b) and (b + c > a):
    p = (a + b + c) / 2
    s = (p * (p - a) * (p - b ) * ( p - c ))** 0.5
    print(f"dien tich hinh tam giac la {round(s,1)}")
else:
    print("day khong phai la 3 canh cua 1 tam giac")
# Out:
# dien tich hinh tam giac la 6.0

# %%
#1.7
s = input(("nhap day ky tu: "))
print( s[4], s[8])
# Out:
# r i

# %%
#1.8
name = input("ten chu ho: ")
last = float(input("chi so thang truoc: "))
now = float(input("chi so thang nay: "))
sum = now - last
if sum <= 50:
    money  = sum * 1984
elif 50 < sum < 100:
    money = (50 * 1984) + (sum - 50) * 2050
elif 100 < sum <= 200 :
    money = (50 * 1984) + (50 * 2050) + (sum - 100) * 2380
elif 200 < sum < 300: 
    money = (50 * 1984) + (50 * 2050) + (100 * 2380) + (sum - 200) * 2998
elif 300 < money <= 400:
    money = (50 * 1984) + (50 * 2050) + (100 * 2380) + (100 * 2998) + (sum - 300) * 3350
else:
    money = (50 * 1984) + (50 * 2050) + (100 * 2380) + (100 * 2998) + (100 * 3350) + (sum - 400) * 3460
print("Ho va ten: ", name)
money = money * 1.08
print(f"tien phai tra la: {money:.0f}")
# Out:
# Ho va ten:  a
# tien phai tra la: 1855505

# %%
#2.1
n = int(input(''))
if n % 2 == 0:
    print("n la so chan")
else:
    print("n la so le")
# Out:
# n la so chan

# %%
#2,2
n = int(input(''))
if n & 10 == 5:
    print('TRUE')
else:
    print('FALSE')

# %%
#2.3
n = int(input(''))
if (n % 3 == 0) and (n % 5 == 0):
    print('TRUE')
else:
    print('FALSE')

# %%
#2.4
age = int(input('nhap tuoi: '))
if n <= 18:
    print('du tuoi bau cu')
else:
    print('chua du tuoi bau cu')

# %%
#2.5
a,b = map(float, input('nhap a b: ').split())
if a == b:
    print('hai so bang nhau')
elif a > b:
    print('a lon hon b')
else:
    print('a nho hon b')

# %%
#2.6
s = input('nhap ky tu: ')
if '0' <= s <= '9':
    print(f"{s} la ky tu so")
else:
    print(f"{s} la ky tu chu cai")

# %%
#2.7
score = float(input("Nhập điểm của bạn: "))

if score >= 8:
    print("Gioi")
elif score >= 6.5:
    print("Kha")
elif score >= 50:
    print("Trung binh")
else:
    print("yeu")
# Out:
# Gioi

# %%
#2.8
year = int(input("Nhap nam: "))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f"{year} la nam nhuan")
else:
    print(f"{year} khong phai la nam nhuan")

# %%
#2.9
num_name = ['Không', 'Một', 'Hai', 'Ba', 'Bốn', 'Năm', 'Sáu', 'Bảy', 'Tám', 'Chín']
num = int(input("Nhap so nguyen tu 1 den 9: "))
if 0 <= num <= 9:
    print(num_name[num])
else:
    print("So khong hop le")
# Out:
# Hai

# %%
#2.10
sc = float(input("Nhap so diem: "))
if sc >= 4 :
    print('qua mon')
else: 
    print('hoc lai')

# %%
#2.11
birthday = input("nhap nam sinh ") 
age = 2025 - birthday
if age >= 18:
    print("ban da du 18 tuoi")
else:
    print("ban chua du 18 tuoi")
